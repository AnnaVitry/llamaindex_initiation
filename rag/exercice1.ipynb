# %% [markdown]
# ## Exercice 1 : Créer un RAG avec LlamaIndex avec des IA locales

# %%
# Installation de modules
# pip install llama-index
# pip install llama-index-llms-ollama llama-index-embeddings-ollama

# %%
# 0) Importer les modules
from llama_index.llms.ollama import Ollama
from llama_index.embeddings.ollama import OllamaEmbedding
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings

# %%
# 1) Configurer le llm local (ollama)
llm = Ollama(model="llama3", request_timeout=60.0)

# %%
# 2) Configurer le modèle d'embeddings local
embed_model = OllamaEmbedding(model_name="nomic-embed-text")

# %%
# 3) Ajouter les modèles dans le setting
Settings.llm = llm
Settings.embed_model = embed_model
Settings.chunk_size = 1024        # max tokens par chunk
Settings.chunk_overlap = 100      # tokens en commun entre deux chunks

# %%
# 4) Ingestion des documents (avec `SimpleDirectoryReader`) + indexation de la base documentaire (avec `VectorStoreindex`)
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

# Charger tous les documents depuis le dossier "data"
documents = SimpleDirectoryReader("data").load_data()
index = VectorStoreIndex.from_documents(documents)
# Vérification
print(f"Nombre de documents chargés : {len(documents)}")
print(f"Extrait du premier document : {documents[0].text[:200]} ...")
# Out:
# 2025-11-07 14:24:49,490 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:25:12,287 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:25:34,411 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:25:54,195 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:26:11,903 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:26:31,239 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:26:51,145 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:27:11,005 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:27:31,096 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:27:44,137 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:28:00,496 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:28:15,617 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:28:31,957 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:28:54,831 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:29:14,715 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:29:29,941 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:29:45,676 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:30:04,920 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:30:24,014 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:30:42,465 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:31:00,123 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:31:16,242 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:31:34,071 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:31:51,357 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:32:14,367 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:32:36,223 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:32:56,203 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:33:08,432 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:33:23,094 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:33:40,896 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:33:57,742 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:34:16,488 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:34:31,907 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:34:48,545 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:35:08,670 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:35:28,486 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:35:44,076 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:36:00,399 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:36:17,438 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:36:34,330 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:36:48,378 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:37:03,551 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:37:22,247 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:37:41,001 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:37:57,791 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:38:15,222 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:38:33,577 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:38:48,216 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:39:04,304 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:39:22,892 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:39:38,095 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:39:55,774 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:40:11,631 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:42:26,295 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:42:46,293 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:43:04,320 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:43:17,492 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:43:34,505 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:43:49,985 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:44:06,264 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:44:24,877 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:44:43,537 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# 2025-11-07 14:44:59,971 - INFO - HTTP Request: POST http://localhost:11434/api/embed "HTTP/1.1 200 OK"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 6
#       4 # Charger tous les documents depuis le dossier "data"
#       5 documents = SimpleDirectoryReader("data").load_data()
# ----> 6 index = VectorStoreIndex.from_documents(documents)
#       7 # Vérification
#       8 print(f"Nombre de documents chargés : {len(documents)}")
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index/core/indices/base.py:122, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, **kwargs)
#     113     docstore.set_document_hash(doc.id_, doc.hash)
#     115 nodes = run_transformations(
#     116     documents,  # type: ignore
#     117     transformations,
#     118     show_progress=show_progress,
#     119     **kwargs,
#     120 )
# --> 122 return cls(
#     123     nodes=nodes,
#     124     storage_context=storage_context,
#     125     callback_manager=callback_manager,
#     126     show_progress=show_progress,
#     127     transformations=transformations,
#     128     **kwargs,
#     129 )
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index/core/indices/vector_store/base.py:75, in VectorStoreIndex.__init__(self, nodes, use_async, store_nodes_override, embed_model, insert_batch_size, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      70 self._embed_model = resolve_embed_model(
#      71     embed_model or Settings.embed_model, callback_manager=callback_manager
#      72 )
#      74 self._insert_batch_size = insert_batch_size
# ---> 75 super().__init__(
#      76     nodes=nodes,
#      77     index_struct=index_struct,
#      78     storage_context=storage_context,
#      79     show_progress=show_progress,
#      80     objects=objects,
#      81     callback_manager=callback_manager,
#      82     transformations=transformations,
#      83     **kwargs,
#      84 )
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index/core/indices/base.py:79, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      77 if index_struct is None:
#      78     nodes = nodes or []
# ---> 79     index_struct = self.build_index_from_nodes(
#      80         nodes + objects,  # type: ignore
#      81         **kwargs,  # type: ignore
#      82     )
#      83 self._index_struct = index_struct
#      84 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index/core/indices/vector_store/base.py:309, in VectorStoreIndex.build_index_from_nodes(self, nodes, **insert_kwargs)
#     306 if len(content_nodes) != len(nodes):
#     307     print("Some nodes are missing content, skipping them...")
# --> 309 return self._build_index_from_nodes(content_nodes, **insert_kwargs)
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index/core/indices/vector_store/base.py:278, in VectorStoreIndex._build_index_from_nodes(self, nodes, **insert_kwargs)
#     276     run_async_tasks(tasks)
#     277 else:
# --> 278     self._add_nodes_to_index(
#     279         index_struct,
#     280         nodes,
#     281         show_progress=self._show_progress,
#     282         **insert_kwargs,
#     283     )
#     284 return index_struct
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index/core/indices/vector_store/base.py:231, in VectorStoreIndex._add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     228     return
#     230 for nodes_batch in iter_batch(nodes, self._insert_batch_size):
# --> 231     nodes_batch = self._get_node_with_embedding(nodes_batch, show_progress)
#     232     new_ids = self._vector_store.add(nodes_batch, **insert_kwargs)
#     234     if not self._vector_store.stores_text or self._store_nodes_override:
#     235         # NOTE: if the vector store doesn't store text,
#     236         # we need to add the nodes to the index struct and document store
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index/core/indices/vector_store/base.py:138, in VectorStoreIndex._get_node_with_embedding(self, nodes, show_progress)
#     126 def _get_node_with_embedding(
#     127     self,
#     128     nodes: Sequence[BaseNode],
#     129     show_progress: bool = False,
#     130 ) -> List[BaseNode]:
#     131     """
#     132     Get tuples of id, node, and embedding.
#     133
#    (...)    136
#     137     """
# --> 138     id_to_embed_map = embed_nodes(
#     139         nodes, self._embed_model, show_progress=show_progress
#     140     )
#     142     results = []
#     143     for node in nodes:
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index/core/indices/utils.py:176, in embed_nodes(nodes, embed_model, show_progress)
#     173     else:
#     174         id_to_embed_map[node.node_id] = node.embedding
# --> 176 new_embeddings = embed_model.get_text_embedding_batch(
#     177     texts_to_embed, show_progress=show_progress
#     178 )
#     180 for new_id, text_embedding in zip(ids_to_embed, new_embeddings):
#     181     id_to_embed_map[new_id] = text_embedding
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index_instrumentation/dispatcher.py:335, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     332             _logger.debug(f"Failed to reset active_span_id: {e}")
#     334 try:
# --> 335     result = func(*args, **kwargs)
#     336     if isinstance(result, asyncio.Future):
#     337         # If the result is a Future, wrap it
#     338         new_future = asyncio.ensure_future(result)
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index/core/base/embeddings/base.py:473, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     468 with self.callback_manager.event(
#     469     CBEventType.EMBEDDING,
#     470     payload={EventPayload.SERIALIZED: self.to_dict()},
#     471 ) as event:
#     472     if not self.embeddings_cache:
# --> 473         embeddings = self._get_text_embeddings(cur_batch)
#     474     elif self.embeddings_cache is not None:
#     475         embeddings = self._get_text_embeddings_cached(cur_batch)
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index/embeddings/ollama/base.py:92, in OllamaEmbedding._get_text_embeddings(self, texts)
#      90 for text in texts:
#      91     formatted_text = self._format_text(text)
# ---> 92     embeddings = self.get_general_text_embedding(formatted_text)
#      93     embeddings_list.append(embeddings)
#      95 return embeddings_list
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/llama_index/embeddings/ollama/base.py:106, in OllamaEmbedding.get_general_text_embedding(self, texts)
#     104 def get_general_text_embedding(self, texts: str) -> List[float]:
#     105     """Get Ollama embedding."""
# --> 106     result = self._client.embed(
#     107         model=self.model_name, input=texts, options=self.ollama_additional_kwargs
#     108     )
#     109     return result.embeddings[0]
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/ollama/_client.py:377, in Client.embed(self, model, input, truncate, options, keep_alive, dimensions)
#     368 def embed(
#     369   self,
#     370   model: str = '',
#    (...)    375   dimensions: Optional[int] = None,
#     376 ) -> EmbedResponse:
# --> 377   return self._request(
#     378     EmbedResponse,
#     379     'POST',
#     380     '/api/embed',
#     381     json=EmbedRequest(
#     382       model=model,
#     383       input=input,
#     384       truncate=truncate,
#     385       options=options,
#     386       keep_alive=keep_alive,
#     387       dimensions=dimensions,
#     388     ).model_dump(exclude_none=True),
#     389   )
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/ollama/_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/ollama/_client.py:129, in Client._request_raw(self, *args, **kwargs)
#     127 def _request_raw(self, *args, **kwargs):
#     128   try:
# --> 129     r = self._client.request(*args, **kwargs)
#     130     r.raise_for_status()
#     131     return r
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/simplon/Cours/Novembre2025/llamaindex_initiation/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
# 5) Créer un moteur de requête (avec la méthode `.as_query_engine` et `.query`)

# Création du moteur de requête
query_engine = index.as_query_engine()

# Exemple de question
question = "Peux-tu me résumer le contenu des documents ?"

# Obtenir la réponse
response = query_engine.query(question)

# Afficher la réponse
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # 5) Créer un moteur de requête (avec la méthode `.as_query_engine` et `.query`)
#       2
#       3 # Création du moteur de requête
# ----> 4 query_engine = index.as_query_engine()
#       6 # Exemple de question
#       7 question = "Peux-tu me résumer le contenu des documents ?"
#
# NameError: name 'index' is not defined
